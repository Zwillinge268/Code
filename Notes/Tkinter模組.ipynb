# %% [markdown]
# ##匯入及建立主視窗

# %%
import tkinter as tk
win = tk.Tk()         #建立主視窗
win.geometry("720x480")     #設定視窗大小
win.title("主視窗")       #設定視窗標題
win.mainloop()         #等候指令直到視窗關閉

# %% [markdown]
# ##元件
